# %%
import pandas as pd
from abc import ABC, abstractmethod
import statsmodels.api as sm
from collections import namedtuple
from typing import Optional, List
import os

# %%
os.chdir(r"C:\Users\yixia\PycharmProjects\ERPB-Research")

# %%
def get_data():

    return pd.read_csv('erp-macro-factors-time-series.csv')


class Bucket(ABC):

    dependent_variable = 'Excess CAPE Yield'
    group_col_name = 'group'

    @abstractmethod
    def _divide(self, df, feature) -> pd.DataFrame:
        return pd.DataFrame()

    def divide(self, df, feature) -> pd.DataFrame:

        df = df[df[feature].notnull() & df[self.dependent_variable].notnull()]
        df_divided = self._divide(df.copy(), feature)

        return df_divided[
            ['MonthYear', 'Date', self.dependent_variable, feature, self.group_col_name]
        ].set_index('MonthYear')


class QuantileBucket(Bucket):

    def __init__(self, q: int):
        self.q = q

    def _divide(self, df, feature) -> pd.DataFrame:

        df[self.group_col_name] = pd.qcut(df[feature], self.q)
        return df


class BooleanBucket(Bucket):

    def _divide(self, df, feature) -> pd.DataFrame:

        df[self.group_col_name] = df[feature]

        return df


BucketRange = namedtuple('BucketRange', ('low', 'high'))


class CustomizedRangeBucket(Bucket):

    def __init__(self, ranges: List[BucketRange], range_names: Optional[List[str]] = None):
        self.ranges = ranges
        if range_names is None:
            range_names = [f'{r.low} to {r.high}' for r in self.ranges]
        self.range_names = range_names

    def _get_range(self, x):

        for r, name in zip(self.ranges, self.range_names):
            if r.low < x <= r.high:
                return name

        return None

    def _divide(self, df, feature) -> pd.DataFrame:

        df[self.group_col_name] = df[feature].apply(self._get_range)
        df = df[df[self.group_col_name].notnull()]

        return df

# %%
df = get_data()

# %%
def analysis(df, bucket, feature):
    df_grouped = bucket.divide(df, feature)

    try:
        df_grouped_scatter = df_grouped.copy()
        df_grouped_scatter[feature] = df_grouped_scatter[feature].apply(float)
        df_grouped_scatter.plot.scatter(x=feature, y='Excess CAPE Yield', )
    except:
        print('Scatter failed probably due to non numerical feature value')

    try:
        mod = sm.OLS(df_grouped['Excess CAPE Yield'], df_grouped[feature])
        res = mod.fit()
        print(res.summary())
    except:
        print('Scatter failed probably due to non numerical feature value')

    # buckets
    print()
    print('Bucket Basic Stats:')
    print(df_grouped.groupby('group')['Excess CAPE Yield'].describe())
    df_grouped[['Excess CAPE Yield', 'group']].boxplot(by="group")

# %%
# example 1
bucket1 = QuantileBucket(4)
feature1 = 'Fed Fund Effective Rate'

# %%
analysis(df, bucket1, feature1)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      Excess CAPE Yield   R-squared (uncentered):                   0.558
# Model:                            OLS   Adj. R-squared (uncentered):              0.558
# Method:                 Least Squares   F-statistic:                              1039.
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):                   4.12e-148
# Time:                        12:36:52   Log-Likelihood:                          1741.4
# No. Observations:                 824   AIC:                                     -3481.
# Df Residuals:                     823   BIC:                                     -3476.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Fed Fund Effective Rate     0.0055      0.000     32.241      0.000       0.005       0.006
# ==============================================================================
# Omnibus:                       37.170   Durbin-Watson:                   0.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.351
# Skew:                           0.076   Prob(JB):                     0.000281
# Kurtosis:                       2.327   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Bucket Basic Stats:
#                count      mean       std     min       25%      50%     75%  \
# group
# (0.039, 1.79]  207.0  0.039655  0.016006  0.0055  0.029350  0.03700  0.0485
# (1.79, 4.13]   209.0  0.028700  0.014724 -0.0109  0.018500  0.02610  0.0345
# (4.13, 6.47]   202.0  0.023842  0.024605 -0.0152  0.008525  0.01590  0.0261
# (6.47, 22.0]   206.0  0.053417  0.029145 -0.0118  0.029275  0.05665  0.0804
#
#                   max
# group
# (0.039, 1.79]  0.0920
# (1.79, 4.13]   0.0985
# (4.13, 6.47]   0.0881
# (6.47, 22.0]   0.1080

# %%
# example 2
bucket2 = BooleanBucket()
feature2 = 'In Recession'

# %%
analysis(df, bucket2, feature2)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      Excess CAPE Yield   R-squared (uncentered):                   0.175
# Model:                            OLS   Adj. R-squared (uncentered):              0.174
# Method:                 Least Squares   F-statistic:                              360.7
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):                    4.13e-73
# Time:                        12:38:00   Log-Likelihood:                          2428.8
# No. Observations:                1706   AIC:                                     -4856.
# Df Residuals:                    1705   BIC:                                     -4850.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# In Recession     0.0530      0.003     18.992      0.000       0.047       0.058
# ==============================================================================
# Omnibus:                      115.881   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              143.300
# Skew:                           0.635   Prob(JB):                     7.63e-32
# Kurtosis:                       3.635   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Bucket Basic Stats:
#         count      mean       std     min     25%     50%     75%     max
# group
# False  1269.0  0.044409  0.040222 -0.0258  0.0167  0.0327  0.0652  0.2172
# True    437.0  0.052957  0.053306 -0.0119  0.0099  0.0424  0.0733  0.2353

# %%
# example 3
bucket3 = CustomizedRangeBucket(
    ranges=[BucketRange(low=0, high=5), BucketRange(low=5, high=10), BucketRange(low=10, high=15)]
)
feature3 = 'Unemployment Rate'

# %%
analysis(df, bucket3, feature3)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      Excess CAPE Yield   R-squared (uncentered):                   0.639
# Model:                            OLS   Adj. R-squared (uncentered):              0.639
# Method:                 Least Squares   F-statistic:                              1596.
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):                   1.26e-201
# Time:                        12:39:22   Log-Likelihood:                          1811.7
# No. Observations:                 902   AIC:                                     -3621.
# Df Residuals:                     901   BIC:                                     -3617.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Unemployment Rate     0.0072      0.000     39.948      0.000       0.007       0.008
# ==============================================================================
# Omnibus:                      213.639   Durbin-Watson:                   0.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              394.841
# Skew:                           1.428   Prob(JB):                     1.83e-86
# Kurtosis:                       4.533   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Bucket Basic Stats:
#           count      mean       std     min       25%      50%       75%  \
# group
# 0 to 5    336.0  0.038065  0.038511 -0.0152  0.012850  0.02420  0.051025
# 10 to 15   14.0  0.079164  0.023127  0.0443  0.055225  0.08705  0.098625
# 5 to 10   552.0  0.045443  0.027505  0.0031  0.024775  0.03760  0.063150
#
#              max
# group
# 0 to 5    0.1334
# 10 to 15  0.1038
# 5 to 10   0.1436
